# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import re

# %%
path = './haruto_shura.txt'

# %%
bindata = open(path,'rb').read()

# %%
text = bindata.decode('shift_jis')

# %%
print('Size of text:', len(text))
# Out:
# Size of text: 60070

# %%
#charsにテキストに出てくる文字を整列して格納する
#set()では重複したtextで重複している文字を削除している
#例）set([1,2,3,3,2]) = [1,2,3]
chars = sorted(list(set(text)))

# %%
print('Total chars:',len(chars))
# Out:
# Total chars: 1684

# %%
#numerate(chars)→forループをiがカウントアップするごとにcharの添字も同時に増やしてくれる。
char_indices = dict((c,i) for i,c in enumerate(chars))

# %%
indices_char = dict((i,c) for i,c in enumerate(chars))

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []

# %%
#sentencesにtextをmaxlen文字ずつ格納する
#next_charsに次の文字（一文字）を格納する（sentencesに格納した文字列の次の文字）
for i in range(0,len(text) - maxlen, step):
    sentences.append(text[i:i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
#テキストのベクトル化

# %%
#Xを初期化[0]→40文字ずつに区切った文章の合計の数
#[1] → 文章の文字列（maxlen)
#[2] → テキストに出てくる「重複している文字を除いた」文字数
#以上のスケールでbool型で初期化
X = np.zeros((len(sentences),maxlen,len(chars)),dtype=np.bool)

# %%
y = np.zeros((len(sentences),len(chars)),dtype=np.bool)

# %%
for i,sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        #対象の文字列の中で使用されている文字のコードに「1」をたてる
        X[i,t,char_indices[char]] = 1
    #i番目の文字列の予想文字のコードに１を立てる
    y[i,char_indices[next_chars[i]]] = 1

# %%
#モデルを定義する

# %%
#kerasで使用するNNの座（Sequential)を定義する
model = Sequential()

# %%
#LSTM(第一引数:隠れ層(128) 第二引数：LSTMに入力するデータの形の指定（（バッチ数）（step数）（特徴の次元）)
model.add(LSTM(128,input_shape=(maxlen,len(chars))))

# %%
#Dence()；隠れ層のノード数を指定する
model.add(Dense(len(chars)))

# %%
#出力層に対しての処理
model.add(Activation('softmax'))

# %%
#optimizer→【名詞】最適化ルーチン
#RMSprop→勾配法の一種(Adagradの改良版)0.01は学習率
optimizer = RMSprop(lr=0.01)

# %%
#モデルの作成（実行は別）categorical_crossentropyは損失関数の一種
model.compile(loss='categorical_crossentropy',optimizer=optimizer)

# %%
#二項分布に従った最大の予測値の入っている添字を返す
def sample(preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    #二項分布から対象となるものの確率を取り出す
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1,60):
    print()
    print('-' * 50)
    print('繰り返し回数：', iteration)
    #モデルの学習を行う
    #bach_size(一回に処理するデータの数)
    #epochs(何回データを処理するか)
    model.fit(X, y, batch_size=128,epochs=1)
    #モデルの学習をどこから始めるかランダムで決める
    start_index = random.randint(0,len(text)-maxlen-1)
    
    for diversity in [0.2,0.5,1.0,1.2]:
        print()
        print('-----diversity', diversity)

        generated = ''
        #40文字ずつ取得してsentenceに格納
        sentence = text[start_index:start_index + maxlen]
        generated += sentence
        print('----- Seedを生成しました：'+ sentence + '"')
        sys.stdout.write(generated)

        #次の文字を予測して文字を足していく処理
        #40文字から次の400文字を予測する
        for i in range(400):
            x = np.zeros((1,maxlen,len(chars)))
            #文字列の中から一文字ずつ取り出して使用されている文字にフラグを立てる
            for t,char in enumerate(sentence):
                x[0,t,char_indices[char]] = 1.

            #モデルの予想を行う（verbose=進行状況の表示の制御。0:表示なし　1：プログレスバー 2:各試行ごとに一行
            #0番目の予測値
            preds = model.predict(x, verbose=0)[0]
            
            #次の予測値の可能性が最も高い確率のインデックスを戻す
            next_index = sample(preds,diversity)
            #対象の文字コードを取得
            next_char = indices_char[next_index]

            #予測文字を予測文章に足していく
            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()

        print()
# Out:
# --------------------------------------------------
# 繰り返し回数： 1
# Epoch 1/1
# 20167/20167 [==============================] - 55s 3ms/step - loss: 2.0748
#
# -----diversity 0.2
# ----- Seedを生成しました：そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだ"
# そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだつてゐる
# 　（あんまり　　しつていてゐる
# 　　　　それからすこかにすからです）
# 　（あんまり　　　しつぱいにあまり
# 　　　　　　（そらですか）
# 　（どうかにといふおふのは
# 　　　　　　　　　　　　　　　　　　　　　　　　天です）
# 　　（いちのんのはひかりのかかしたり
# 　　　　それからすこかにかたちられたらしい）
# あんまりあんまりはひかりのかかしればなにからうがらす
# 　　（それはすこかにあたまでせう）
# 　（あんまり　　　しつぱいによつけらうない
# 　　　　それからすこかにすこかです）
# 　（あんまり　　したつてゐる
# 　　　（そんなにひかりのきれをなる）
# どんなにかしたらうにつたひとは
# あたまはいままへでする
# 　（あんまり　　しつていてゐる
# 　　　　　それからすこかにかられてゐる）
# そんながそしはしたちにそつてゐる
# 　　（そのそらはそらは
#
#
# -----diversity 0.5
# ----- Seedを生成しました：そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだ"
# そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだつてきまり
# ［＃地付き］※［＃始め二重括弧、1-2-54］こんなこここはここでです）
# 　（ちらんとしくろくてゐるのだ
# 　　　　そしからすこかにかたちられ）
# 　　　　　（いちどん　はひかりにかぶれてゐる）
# すんとがあんまりくらくらくらくるとき
# ひとりのアにかやうなあた
# 　　　　それどこここよあどこどへて
# 　　　　青いガラスのあかり
# 　　　　　　　いまです）
# 　　（そんなられるのです
# 　　　　こつちのここならなかかしく）
# 　　　（ましろばらしいつぱいになまた
# 　　　　　ここしなさいふどでなみを※［＃終わり二重括弧、1-2-55］
# 　※［＃始め二重括弧、1-2-54］こんなここでではここでこんですか）
# 　（どうどここのはひかりのきれを
# 　　　　　　おれたちのふのが
# 　　　　ましさら　　よつぱいに生よが
# 　　　　それからすこかにかたちので）
# 　　　そらからしか
#
# -----diversity 1.0
# ----- Seedを生成しました：そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだ"
# そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだをへんなする
# それはいまるでそらを
# 雲と風景に地感下は
# なにペほうもつたひとつきたらだ
# 　　　　まばでオルとンふのまででし）
# 　　（水）
# 　（底［の水　赤犬では
# 　　ここなとだからからそれ）
# みんとお居がるあのつるからくしい
# 新らならぐる雲のの追では
# もうまりことはみやしやうだいやうよるからは
# 雲のほんたのし子をもまるす
# きはやなすをS月れてげらゆればらら
# し子七口背中です
# わたしの穂《ちや》　お》なの二げ
# はつかなし子なきだす
# 風がさびしよ雲の信ツ」も
# もう電金のみを七つわたのだつへ
# 　　　うしいてマを空へすこで
# 　　もうでひと月はシヤ）
# 　　　（よこたウみたりの）
# 　（四めた青くらそ遠ものよる
# 徳し水がくるくない）
# 然ら折はかたかu信れ
# 　　　（あしい　そのです
# 　　くさつきやしろけれてゐる
# 　（はめんふかんたひとの天球）
# 　　　（
#
# -----diversity 1.2
# ----- Seedを生成しました：そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだ"
# そこでゆつくりとどまるために
# 本部まででも乗つた方がいい
# 今日ならわたくしだのギるとば
# りさんかを石めまつた車だらうまから
# こんなにみなさきなからゆれれのなかを
# そのこぞらを農へかをぺ燈たまらじ毛
# は
# 過山のがぐれつたられる
# 向ふのおなではない）
# いのひの馬車は小ちですむかちになら
# すんでは雪がさびやう色すよかのうた液をろが
# ただかにそどまはこんなちら何と点灯い来る
# こばさくもがせあ烏月　レき《やう》き提のが
# 光いやあひたひかりかけ犬光の｜：《じやち農八9吊頁前冬皮つたひどうでお着てある）
# 行つのくれたへや彩ひ神いのテカラも動野佐がそかぴの来る）
# 尾ばじちら
# ハ水パ ヶRにみけ査まくる
# にひまりは生じとのりとわたよし
# こ枝は十ゆる朝のなかに
# はたらないたぜお水ぼろのとどきのやうしは
# 　（日光いた心七空だ柱だ章ツ）
# それの波、えベやつだむく》のダカル
# ほんまつ生トば
# ねす波截松準年書いてゐる
# 　（一九三年字どうどんここどド
#
# --------------------------------------------------
# 繰り返し回数： 2
# Epoch 1/1
# 20167/20167 [==============================] - 58s 3ms/step - loss: 1.9206
#
# -----diversity 0.2
# ----- Seedを生成しました：》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川"
# 》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川のちひとはそらに
# いまは青ぐらのやうにとつてゐる
# 　　（かれたのかにし子をおものだ）
# あたしくなるいとうといつたいとだ
# わたくしのここのがひといろのうとい
# またえるのだかのかげしろの
# ためにはいつ青いいにあるとおまたつたのだ
# わたくしのここのひとはからくとのこつとのまた
# そのやうなられたのだから
# いつたいまだんなんかしくらくるとき
# 　　（おれはいまへんばんなにみちのふただ
# 　　　　　（おきないのだからのあないただ
# 　　　（いちどほのひどいのかなしから
# 　　　（いちどうのひとりのかなし
# 　　　（いちどほのひどりをみんなする
# 　　　（いちはそのりにはひがり
# 　　（おきないのは
# 　　　（おしたりのこのでは
# 　　　（いゝえ　　　　　　たつかに
# 　　　（いちどうのこんながつてゐる
# 　　（どうしやしかないまです
# 　　（あたいはそのつきならない
# 　　　（いちど
#
# -----diversity 0.5
# ----- Seedを生成しました：》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川"
# 》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川のやうにしくのましやなぎなみかない
# 　　（いちどうなかたし子のたちのみたしい
# 　　　（おした過ぎのことはからをするときです
# 　　（あめたちのひかりをあんまり　　きれて
# 　　　　　（おも　ろのやうにもちひない
# 　　（それは青いくしのちのまつたのだ
# 　　　（いまだちのつてはらにみたのだ
# 　　　（おい　ろのひとりにあるしなつてしれた）
# 　（どうなひの青わたくしのだこ　のは
# 　　　（じやつぎりもあいいだ
# 　　（あたいはそのしなみにしたのだ
# 　　　（わたくしはそれにつてひつすぎなつたのだ
# 　　　（どう》のこのひらはいまごろか
# 　　（ぶんだし子のなかにはいつたりのだ
# 　　　（いちや　それだのだ
# 　　　（いちどんものものは
# 　　　　（いちろんのひかりをかけてゐるとう
# 　　　（いちさんのひとりのかなしから
# 　　　（いちどん　しつかりのない
# 　　　　　　　　　　たれたい
#
# -----diversity 1.0
# ----- Seedを生成しました：》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川"
# 》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川のちひよはりかず
# クの穂んまに-りさまに小さなちやみなる
# エんかき尊れ山の黒ツカみでよ
# 雲と松パなに　みちちよつ北第まがへ
# 野原はの流みにもみちひ湧ら雪てゐるのか
# 変たしてかんがひとかなつくにはなつたのだ
# わたくしのかれもえ雨しゐ羅のだキ
# そのちよりと着てゐる　わたいでうます
# ちやうなとし子にあたたとおまなけろと
# 　　（を日め　ここの悪金《アかす右》た青ルさし
# 　　　日光《雲をパ》のな下のあぶらさつ東がひる
# は赤きされる流の
# また云つた上にかつたのだ
# 手のなげとつぶはこくス射おまへの亜鼠
# えた※［＃始め二重括弧、1-2-54］鳥た歌し子火をもあるの青く光《らカか》の穂
# 外ムにがたけんのにスの雲aの光ぶれをぶつてはまつすながき
# いまやならそた端行つたつきからうのいいいつすきと角た可…
# わたもしのうちろはほしつとりある
# からやしぎ　　　それとのグめで
# ［＃
#
# -----diversity 1.2
# ----- Seedを生成しました：》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川"
# 》をよどませ
# あやしいよるの　陽炎と
# さびしい心意の明滅にまぎれ
# 水いろ川の因明に川がさし緑のやうに査が生柱たつらさい
# まつしい気花までそに小さいことばみん新
# わたくしのかもやつて来け黄の並滅ら
# わたくしはた悪し浮ばかけすますえ枝は
# ヤ射と灰十日山の
# くもうよこと白定
# ゝくどりえる悪5燃《利》れ夫言ハ
# そればあたくろ馬のぴかに七きたつとが
# 四しなみにはそ2硫気チといす
# 向ふのな液にはひだつてゐると
# 日波はきめ燐丘えます校月が
# 春のせら張にさま（の大ひ味を
# その　線わたくしが行つたかへがべが）
# 集雨たち一三年樺のあかり
# 風の 石ドがで赤いひとはなつてゐるし飛
# 真R底人本薄らなしかみがり
# その（ん私んちふんの立つて感り
# なぜ生えなどくもしてスがまつとよるとか
# ますこで用んが万可毛《林にちい》やしてとましならなむをみじ松倉人のみみん城の平ら
# 黄ゆのー　な十ふのラ無ものうな
# 　　動ダールさはやし
# 　　おいさんしろのにシふへは
#
#
# --------------------------------------------------
# 繰り返し回数： 3
# Epoch 1/1
# 20167/20167 [==============================] - 59s 3ms/step - loss: 1.7873
#
# -----diversity 0.2
# ----- Seedを生成しました：は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯が"
# は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯が《つくし》にもうよるときなが
# あたらのとこつたこのはそらだらだ
# もうまいいろのやうにしまが
# あたらのいままでは
# あたらのいままでは
# いまへはそのひとつてりんます
# そのやうなしやしなみのなかの
# そのなにならなつとひかつたのうだ
# そのたらかんといてろくろのかげして
# そのやうなしみをももあるいもうしてしまつた
# そのたのここのあたりは
# いまではあんまりですなか
# このこのはいしくかんから
# するきはあめたこここのことばらばことは
# そのやうにちひとつかなぐらのにも
# そのやうなしやかなくらつとみんたい
# 　　（そのはんのここはそのやしなく
# 　　　　それどのここでこここのくらつとしくから
#
#
# -----diversity 0.5
# ----- Seedを生成しました：は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯が"
# は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯がぱいそころにして
# そのなにからなにかたちの
# そのちらひとつてかられたたらわたくしのか
# そのやうな金いまです
# 一本の子もりを
# プんのここにもつてしまつたらうか
# 　　　　んだからのにかなつたのにつたひる
# 　　　そのなにもしくたちのあかりのだ
# いまはゆれるのはいちやんとぎなつてからうのがる
# そのはいまでこんなにまる
# そのやうな黒こかならの
# きのかにあめたのだだの
# そのひとつてもそれ
# いままでするとのです
# いままでは黒いるのは
# こんなにみちをふたののここで行つて
# おい　さんなにかたのしくおもただ）
# おまへのこのんではんでしくかけれたら
# このは
# なかれたいほ草のなかを
# とし子た子のあたいいどまをおまへのあたりだない
# そのやうにちやんなくろく
# 松倉山のこののゐるのは
# あんまりするがひかりをする
# こんなにみちかけのことのからで
# ［＃地付き］（一九二二、四
#
# -----diversity 1.0
# ----- Seedを生成しました：は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯が"
# は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯がぬ四んるツシ山ドす
# 地でもなちのあからいつぱいにどんやくとい因じ
# また日の｜光《あゆるりは》を下のび
# すつかりの二けにひがり
# なににからひといもうまつする
# 白いいい霧のぜんそ育移べる※［＃終わり二重括弧、1-2-55］
# 　さつきれらなつて竹とふるで※［＃終わり二重括弧、1-2-55］
# 　※［＃始め二重括弧、1-2-54］おまは　も天えるのは　行いねがひとば
# 　　　菩室のやいちひついみに象つてゐる
# 　　　いい時三《だ原》しのピがし
# 　　　こんな禁燃ずのの木ままで
# 明　　ゐあい　なめのなふは
# 　　そのひとは青いくバのたのほどなから
# 夜のひやつけるのは微いまのだ
# ぶらさうしく九めにじたひたる
# 間を　あたち七つぱい跡ずて来るのは
# そこでははガしまりぼろのさまに
# づつて一あくるときる日のでぎ
# こやしはここでゐるのだ
# すみをはきれる※［＃終わり二重括弧、1-2-5
#
# -----diversity 1.2
# ----- Seedを生成しました：は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯が"
# は天の楽音）
# 噴火湾のこの黎明の水明り
# 室蘭通ひの汽船には
# 二つの赤い灯が眩つて鳴らる
# 往さもe　し光《くトう》ではね
# 　　それ
# 色木が《つく》》に羽ふこの｜づき
# むのをもんと河外地な眼はゆまるもう
# ゐらあ射《ひ耕天た俊だ　うさうないへふ
# 'いた小さは十室の赤くわら
# い熟発風やつぎぎればあや青ぎ朝過朝のばんし並工サゆ
# そらな馬属あマこあち萱くて皮ければなげだ
# 弁きつりた物ねこんなつてるや※［＃終わり三重括弧、1-2-55］
# 羅mランな小は夜はう見ぱつ避立たやう
# 　方師ど枝なひるひとわから
# つて棲はすきなつてゐるのだ
# ［＃草き二夏ば日食の大-幽-一んたきあぶき
# 岩　《》ラ青《ねガ》のたはじくのだかつてゐるた※［＃終わり二重括弧、1-2-55］
# 　居だ大※［＃始め野空し一急ら炭どこ室）
# もうんな原光のらごくもつてから……
# ［＃得わを中］
# ［＃「おき進おきぼ二める岩風は羽《銀聖》の青に地き雲が一づれ）
# 1年月ペ年子ロ影尼）
# みん
#
# --------------------------------------------------
# 繰り返し回数： 4
# Epoch 1/1
# 20167/20167 [==============================] - 58s 3ms/step - loss: 1.6689
#
# -----diversity 0.2
# ----- Seedを生成しました：1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山"
# 1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山《つきら》き》のなかに
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　　おまへのすべてのこ
#
# -----diversity 0.5
# ----- Seedを生成しました：1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山"
# 1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山の雲のすももだか）
# これらのあかしいのでしなつかならない
# 　（いつぱいちよんといつてゐる
# 　　　どうどうしまりのなかしさなして
# 　　　　　わたくしがそこをくつてゐるとどまなみか
# 　　　　これどもわれくしがをすこまでです
# 　　　（そのといのここはたつてゐる
# 　　　（ここどいちひとのみちのまがり
# 　　　ここへがみんなりをつてゐる
# 　　　（ここであるまでいびしく）
# 　（そのではあんまでする
# 　　　それからのこかにあるいのうならだ
# 　　　　これらのここのあるまのなかは
# 　　　ここしはどしものなかなくかし
# 　　　　ここどのちひをつたるとが
# 　　　　わたくしはたつてゐる　　おもおいのだから
# 　　　　　　　　　　　　　　　　　あたつはいつたもうに
# 　　　　　　　　　おまぐさまですかんに※［＃終わり二重括弧、1-2-54］こんではあされらか※［＃「われくき］
#
#
# ［
#
# -----diversity 1.0
# ----- Seedを生成しました：1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山"
# 1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山ゝ《ばうげん》んばしてすます
# 　（だふた林と※［＃「二七お陽」は行一」だび
# ねき二つ平四かないい
# もうぶちらが永とき》い南の日光《ト括をし》
# だらださな　かしてゐるのも
# ※［＃始め二重括弧、1-2-54］こであかかまで
# 　（し子まもひアをしスかけれどなから
# 　　　　ま十ひどまでしたがない）
# みんなさびしい岩の上ハだからろかつたもう
# まぐさいの日口の影あみみ
# そちならりをしてゐる
# そつはわあたこ沢のみちを鳴まで
# ましや２む森-ムくをじをお…ぐら
# 雲照らん雲がゞけてゐるとです
# むうさうどそ5ゆあるとやみ
# 雲と上にはかれですゐ
# ひとものは
# アバももうです
# やうて雲のばいになけれた左空しや
# わたくしは然までしじらに中さへ
# プぐさがひとにするかない
# いつた銀のぴきの銀青《くわうへう》い
# まつたくさあなつた※［＃終わり二重括弧、1-2-55］
# 　※［＃始め
#
# -----diversity 1.2
# ----- Seedを生成しました：1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山"
# 1-94-5］気《かうき》をふかみ
# 楢と椈《ぶな》とのうれひをあつめ
# 蛇紋山ら《つきい》した十月四まあり
# ぞれはぼいじ松の変もして
# きた新らな亜発じ
# 切らのと骨影ないて底ぐらへ
# ぱい月は磨　ルを万へてゐる
# 　　（の月だかたい終云の」は飛ねふたヶ分）
# 　（今外ら5風はそ圏そら）
# 終り二修ハ八気く澱
# げてはわれたばさまで二羽と土へか）
# んまで台一してりひめをするからが犬の烏馬に
# ん（なら明によつた来て乗へある提だ
# ほんた式にあまつたべんだしから
# 、死摩てあるのは今をちられる者時《はい》光ガで《よてよく》のぼとまで
# おれもちアガ天c電アはしさまら空アが
# ま　　　それで出す日）森いにゐる
# 木きのりの立（かけでごければなさまです
# た第ややくして痛向んまぶ
# つたさうに遠げそしてにきらがらひかけ
# れてoぶんつまぐさ岩をうて華け）
# a分
# かれe月夜岩《かうくそ》
# う　（
# 　青　ほんた発一日もやあぎまでんうぶら）
# （皺に式星あかくじがめ
#
# --------------------------------------------------
# 繰り返し回数： 5
# Epoch 1/1
# 20167/20167 [==============================] - 56s 3ms/step - loss: 1.5647
#
# -----diversity 0.2
# ----- Seedを生成しました：リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃え"
# リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃えれて
#
#
# -----diversity 0.5
# ----- Seedを生成しました：リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃え"
# リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃えれて
# 　　　　　　　　　　　　　　　わたくしろのむつた
# 　　　　　　　　それともみちかんだのですか）
# 　　　　（ああたいろのここでもつてゐる
# 　　　　　　それを水すてゐる　　　　いましろのといになつてゐる
# 　　（あめたいろのぼけろいちやつてゐる）
# わたくしはそこはらもことらからからして
# そのきらからしつから
# そのやうにすことりです
# 　　（ありたう　それをおまたさここよらら
# 　　　　　あめたのその大どなかで
# 　　　　ましたりときなくのうとい）
# 　　（える　　　　いましろのここででる
# 　　　　　　　　　　　　　　　　　たしかにとしてきたううだ）
# 　　（あめたいく　　あたつは羽たした）
# 　（やうだい　　　まつたらことが
# 　　　　それとのつてもの
# 　　　　　　　　　たしかにかしてろもりつてゐる
# 　　　そして
# 　　　　　（おしたひとつたたりのうです
# 　　　　こ
#
# -----diversity 1.0
# ----- Seedを生成しました：リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃え"
# リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃えなつてき 空だ）
# ＋んな左くらつとむみただ）
# ［＃地付き］（一九二二、一九二七）
# ［＃改ページ］
#
# ［＃２字下げ］感ろふコ｜ク※［＃「見てゐるし］
#
# ほ２記下の］とことわ
# 　　　　考ちめんに左をを光て得れる）
# あの火を巻倚て波んな田
# その丘《こわんのは月は車りの吹き
# しづたはわたれたふのまるきと馬風とエほひの種きた
# eずた　それかり言へたれdを来てしづれ）
# ちひよりとなつて飛たへなる
# ぢきもちにみてしたみは……きながさだ
# けらな車がいまだだんもうの考みだの
# ていふのまで行いつた雲のゆつろ陽なら
# おまへはこここがりのちひ線い物ろのたつきかり
# わたくしはたことでもこんならすなか
# すこでも雲をした風が
# その緑はではるもしだにつかあしいい》のなかの
# 死の消えあありんたひとい雲だす
# いつたいと穂　向気の交どででも向たし
# 酸馬大ためにもあるいの声をきく巨き
#
# -----diversity 1.2
# ----- Seedを生成しました：リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃え"
# リカサスートラ）
# 結晶片岩山地では
# 燃えあがる雲の銅粉
# 　　　（向ふが燃えけばちふその外おの、」は中見出した
# も水幾ど八べもをごすこどもらみかくから
# 　わたくしははそを万《ス張》　明》が化がみたくとけ）
# あります価ー工巣のなかで
# びしく光るはらんこもが
# その毛へ二むしザひとにあり
# けし見あんまりにじとふや大てゐる
# すすきあわたくスにて｜川のまへ
# 　　炭遠生大て赤く腐どはばばたり
# 　　　それはエなエの間ぶ
# 　　　黒丘仙あるしろの向でりれただ）
# 言つたたの鮮方真の食夫でも気だ
# せい海間のうつ飛けの雲で穂た
# 飛樺のきんまに青かけなふ
# この毛明ぶちろくてゐる
# リは
# 道つまりも朧黄来です
# ア中ツ＋夕て黒い＊せうせし
# 　ああありでは銀大てゐる
# 百進無壁を過第《ろよばよん》の四月ガンル輪
# 四ぬれ庫虚日眼わ、んか小このでた
# ひかりのここの遠火…過礫茶のひる
# 　》のころなかんのやつかもり長をだらひと
# そらのひとつとほた耘レをその輪雲
#
# --------------------------------------------------
# 繰り返し回数： 6
# Epoch 1/1
#  3840/20167 [====>.........................] - ETA: 48s - loss: 1.2388
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-b51276890822> in <module>()
#       3     print('-' * 50)
#       4     print('繰り返し回数：', iteration)
# ----> 5     model.fit(X, y, batch_size=128,epochs=1)
#       6
#       7     start_index = random.randint(0,len(text)-maxlen-1)
#
# ~\AppData\Local\conda\conda\envs\textgen\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\textgen\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# ~\AppData\Local\conda\conda\envs\textgen\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\conda\conda\envs\textgen\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~\AppData\Local\conda\conda\envs\textgen\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:
